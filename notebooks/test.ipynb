# %%
import pandas as pd

# %%
crypto = pd.read_csv("../data/crypto/raw/ND26_crypto.csv")
crypto.head()
# Out:
#    Unnamed: 0 Channel  Year    Degree Level Nationality      Career  \
# 0           0  online  2025      STEM   MSc       China       Legal
# 1           1     f2f  2022      STEM   1st      Turkey     Medical
# 2           2  online  2021      STEM   2nd          ME         NaN
# 3           3  online  2023  Business   PhD       China     Finance
# 4           4     f2f  2021      STEM   PhD       China  Technology
#
#   Crypto type            Crypto usage Crypto knowledge Duration  \
# 0    BTC,DOGE        remittance,trans              +++      4-5
# 1         NaN              remittance              +++        1
# 2     BTC,ETH                   trade                +        1
# 3         BTC  trade,remittance,trans               ++      1-3
# 4         BTC                   trade              +++      NaN
#
#   Trade performance  Remittance amount Crypto knowledge source  \
# 0               NaN               50.0                 friends
# ...

# %%
dropout = pd.read_csv("../data/dropout/raw/ND26_dropout.csv")
dropout.head()
# Out:
#    Unnamed: 0 External    Year  session 1  session 2 test 1  session 3  \
# 0           0        Y  second         58         60      A       62.0
# 1           1        Y   third         96         32      A       86.0
# 2           2        Y   first          0          4      F        NaN
# 3           3        N   third         14          2      B        NaN
# 4           4        N  second         67         16      A       86.0
#
#    session 4 test 2  session 5 test 3  session 6 ind cw group cw final grade  \
# 0       23.0      C        1.0      C       97.0      F        F           B
# 1       93.0      A       44.0      A       24.0      B        A           F
# 2        NaN    NaN        NaN    NaN        NaN    NaN      NaN         NaN
# 3        NaN    NaN        NaN    NaN        NaN    NaN      NaN         NaN
# 4       69.0      A       81.0      D        NaN    NaN      NaN         NaN
#
#    forum Q  forum A  office hour visits dropout
# ...
